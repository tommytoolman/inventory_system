# %%
import pandas as pd

# %%
inv_df = pd.read_csv(inv_file)

# %%
inv_df
# Out:
#              brand name                category name  \
# 0                fender  Guitars>Electric solid body
# 1                gibson  Guitars>Electric solid body
# 2                gibson  Guitars>Electric solid body
# 3                gibson  Guitars>Electric solid body
# 4                fender  Guitars>Electric solid body
# ..                  ...                          ...
# 967  Gibson custom shop  Guitars>Electric solid body
# 968              fender  Guitars>Electric solid body
# 969              fender  Guitars>Electric solid body
# 970              gibson  Guitars>Electric solid body
# 971              gibson     Guitars>Semi-hollow body
#
#                                          external link  product id  \
# 0    http://denmarkstreetonline.co.uk/product-detai...       45069
# 1    http://www.denmarkstreetonline.co.uk/product-d...       45085
# 2    http://www.denmarkstreetonline.co.uk/product-d...       45086
# ...

# %%
# Out:
# Index(['brand name', 'category name', 'product id', 'external id',
#        'product model name', 'product price', 'product price notax',
#        'product description', 'product year', 'product sold', 'product finish',
#        'product in collective', 'product in inventory', 'product in reseller',
#        'collective discount', 'free shipping', 'buy now', 'show vat', 'decade',
#        'product order', 'local pickup', 'available for shipment',
#        'processing time', 'offer discount', 'image url', 'video url',
#        'external link', 'Unnamed: 27'],
#       dtype='object')
