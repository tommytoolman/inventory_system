# %%
import os
from pathlib import Path
from typing import Set

os.getcwd()
# Out:
# '/Users/wommy/Documents/GitHub/PROJECTS/HANKS/inventory_system'

# %%
def list_directory_structure(startpath: str, ignore_patterns: Set[str] = None) -> str:
    """
    Create a formatted directory tree string.
    
    Args:
        startpath: Root directory to start from
        ignore_patterns: Set of patterns to ignore (e.g., {'__pycache__', '.git'})
    
    Returns:
        Formatted string representing the directory structure
    """
    if ignore_patterns is None:
        ignore_patterns = {'__pycache__', '.git', '.env', 'venv', '.idea', '.vscode'}
    
    output = []
    
    for root, dirs, files in os.walk(startpath):
        # Remove ignored directories
        dirs[:] = [d for d in dirs if d not in ignore_patterns]
        
        level = root.replace(startpath, '').count(os.sep)
        indent = '│   ' * (level - 1) + '├── ' if level > 0 else ''
        
        # Add directory name
        rel_path = os.path.relpath(root, startpath)
        if rel_path != '.':
            dir_name = os.path.basename(root)
            output.append(f'{indent}{dir_name}/')
        
        # Add files
        sub_indent = '│   ' * level + '├── '
        for i, file in enumerate(sorted(files)):
            if i == len(files) - 1:  # Last file in directory
                sub_indent = '│   ' * level + '└── '
            output.append(f'{sub_indent}{file}')
    
    return '\n'.join(output)

# Get the current working directory
cwd = os.getcwd()

# Try to find inventory_system directory
current_dir = Path(cwd)
while current_dir.name != 'inventory_system' and current_dir.parent != current_dir:
    current_dir = current_dir.parent

if current_dir.name != 'inventory_system':
    print("Please enter the full path to your inventory_system directory:")
    inventory_path = input().strip()
    if not os.path.exists(inventory_path):
        print(f"Error: Directory {inventory_path} does not exist")
        raise SystemExit(1)
else:
    inventory_path = str(current_dir)

# Print the directory structure
print("inventory_system/")
print(list_directory_structure(inventory_path))
# Out:
# inventory_system/
# ├── .DS_Store
# ├── .env
# ├── .gitignore
# ├── README.md
# ├── TODO.md
# ├── Untitled.ipynb
# ├── alembic.ini
# └── requirements.txt
# ├── migrations/
# │   └── .DS_Store
# │   ├── versions/
# ├── app/
# │   ├── .DS_Store
# │   ├── __init__.py
# │   ├── config.py
# │   ├── database.py
# │   ├── hanks.ipynb
# │   └── main.py
# │   ├── utils/
# │   ├── models/
# │   │   ├── .DS_Store
# │   │   ├── product.old.py
# │   │   ├── product.py
# │   │   └── sale.py
# │   ├── cli/
# │   │   ├── .DS_Store
# │   │   ├── __ini__.py
# │   │   └── import_data.py
# │   ├── integrations/
# │   │   ├── __init__.py
# │   │   ├── base.py
# │   │   ├── setup.py
# │   │   └── stock_manager.py
# │   │   ├── platforms/
# │   │   │   ├── __init__.py
# │   │   │   ├── ebay.py
# │   │   │   └── reverb.py
# │   │   │   ├── vintageandrare/
# │   │   │   │   ├── __init__.py
# │   │   │   │   ├── parser.py
# │   │   │   │   └── scraper.py
# │   ├── static/
# │   │   └── .DS_Store
# │   │   ├── css/
# │   │   ├── images/
# │   │   ├── js/
# │   ├── templates/
# │   │   ├── .DS_Store
# │   │   └── base.html
# │   │   ├── inventory/
# │   │   │   ├── detail.html
# │   │   │   └── list.html
# │   │   ├── errors/
# │   │   │   └── 404.html
# │   ├── routes/
# │   │   ├── .DS_Store
# │   │   └── inventory.py
# │   ├── services/
# │   │   ├── .DS_Store
# │   │   ├── classes.ipynb
# │   │   └── csv_handler.py
# │   │   ├── website_api/
# │   │   │   ├── __init__.py
# │   │   │   ├── client.py
# │   │   │   ├── schemas.py
# │   │   │   └── sync.py
# │   │   ├── ebay/
# │   │   │   ├── .DS_Store
# │   │   │   ├── Untitled.ipynb
# │   │   │   ├── __init__.py
# │   │   │   ├── client.py
# │   │   │   ├── eBay Testing.ipynb
# │   │   │   ├── eBay.ipynb
# │   │   │   ├── ebay_config.yaml
# │   │   │   ├── schemas.py
# │   │   │   └── sync.py
# │   │   │   ├── ebaysdk-python/
# │   │   │   │   ├── .DS_Store
# │   │   │   │   ├── .gitignore
# │   │   │   │   ├── Changes
# │   │   │   │   ├── INSTALL
# │   │   │   │   ├── LICENSE
# │   │   │   │   ├── MANIFEST.in
# │   │   │   │   ├── README.rst
# │   │   │   │   ├── ebay.yaml
# │   │   │   │   ├── setup.py
# │   │   │   │   └── tox.ini
# │   │   │   │   ├── tests/
# │   │   │   │   │   ├── __init__.py
# │   │   │   │   │   ├── test_base.py
# │   │   │   │   │   ├── test_errors.py
# │   │   │   │   │   └── test_request.py
# │   │   │   │   ├── samples/
# │   │   │   │   │   ├── __init__.py
# │   │   │   │   │   ├── calls_with_unicode.py
# │   │   │   │   │   ├── common.py
# │   │   │   │   │   ├── finding.py
# │   │   │   │   │   ├── finditem.py
# │   │   │   │   │   ├── merchandising.py
# │   │   │   │   │   ├── parallel.py
# │   │   │   │   │   ├── parallel_gevent.py
# │   │   │   │   │   ├── policies.py
# │   │   │   │   │   ├── poller.py
# │   │   │   │   │   ├── request_dictionary.py
# │   │   │   │   │   ├── shopping.py
# │   │   │   │   │   ├── storeMeta.py
# │   │   │   │   │   ├── t_http.py
# │   │   │   │   │   ├── test_image.jpg
# │   │   │   │   │   ├── test_perf.py
# │   │   │   │   │   └── trading.py
# │   │   │   │   ├── ebaysdk/
# │   │   │   │   │   ├── .DS_Store
# │   │   │   │   │   ├── __init__.py
# │   │   │   │   │   ├── config.py
# │   │   │   │   │   ├── connection.py
# │   │   │   │   │   ├── exception.py
# │   │   │   │   │   ├── parallel.py
# │   │   │   │   │   ├── response.py
# │   │   │   │   │   └── utils.py
# │   │   │   │   │   ├── poller/
# │   │   │   │   │   │   ├── __init__.py
# │   │   │   │   │   │   └── orders.py
# │   │   │   │   │   ├── shopping/
# │   │   │   │   │   │   └── __init__.py
# │   │   │   │   │   ├── finding/
# │   │   │   │   │   │   └── __init__.py
# │   │   │   │   │   ├── inventorymanagement/
# │   │   │   │   │   │   └── __init__.py
# │   │   │   │   │   ├── policies/
# │   │   │   │   │   │   └── __init__.py
# │   │   │   │   │   ├── http/
# │   │   │   │   │   │   └── __init__.py
# │   │   │   │   │   ├── merchandising/
# │   │   │   │   │   │   └── __init__.py
# │   │   │   │   │   ├── soa/
# │   │   │   │   │   │   ├── __init__.py
# │   │   │   │   │   │   └── finditem.py
# │   │   │   │   │   ├── trading/
# │   │   │   │   │   │   └── __init__.py
# │   │   │   │   │   │   ├── .ipynb_checkpoints/
# │   │   │   │   │   │   │   └── __init__-checkpoint.py
# │   │   │   │   ├── .ipynb_checkpoints/
# │   │   │   │   │   ├── ebay-checkpoint.yaml
# │   │   │   │   │   └── setup-checkpoint.py
# │   │   ├── reverb/
# │   │   │   ├── Reverb_Mass_Upload.csv
# │   │   │   ├── __init__.py
# │   │   │   ├── client.py
# │   │   │   ├── reverb.ipynb
# │   │   │   ├── reverb_inventory_24-01-25 154501.csv
# │   │   │   ├── schemas.py
# │   │   │   └── sync.py
# │   │   ├── vintageandrare/
# │   │   │   ├── __init__.py
# │   │   │   ├── client.py
# │   │   │   ├── empty_bulk_upload_2025-01-21_09-25.csv
# │   │   │   ├── export.py
# │   │   │   ├── schemas.py
# │   │   │   ├── sync.py
# │   │   │   ├── vintage_mappings.csv
# │   │   │   ├── vintageandrare.ipynb
# │   │   │   ├── vintageandrare_inventory_2025-01-21_09-28 copy.csv
# │   │   │   └── vintageandrare_inventory_2025-01-21_09-28.csv
# ├── tests/
# │   ├── __init__.py
# │   └── test_db.py
# ├── docs/
# │   ├── .DS_Store
# │   ├── project-setup.md
# │   └── project-summary.md
# │   ├── instructions/
# │   │   ├── 01 Project structure instructions.txt
# │   │   ├── 02 Project description tech outline.txt
# │   │   ├── 03 requirements.txt
# │   │   └── 04 Additional Documentation Structure.txt
# │   ├── user_guide/
# │   │   ├── faq.md
# │   │   ├── getting_started.md
# │   │   ├── inventory_management.md
# │   │   └── troubleshooting.md
# │   ├── deployment/
# │   │   ├── backup.md
# │   │   ├── configuration.md
# │   │   ├── monitoring.md
# │   │   └── setup.md
# │   ├── api/
# │   │   ├── architecture.md
# │   │   ├── endpoints.md
# │   │   ├── models.md
# │   │   └── platform_integration.md
# ├── scripts/
# │   ├── setup_docs.sh
# │   └── setup_project.sh
# ├── .ipynb_checkpoints/
# │   ├── README-checkpoint.md
# │   ├── Untitled-checkpoint.ipynb
# │   ├── classes-checkpoint.ipynb
# │   ├── eBay Testing-checkpoint.ipynb
# │   ├── eBay-checkpoint.ipynb
# │   ├── hanks-checkpoint.ipynb
# │   ├── logins-checkpoint.ipynb
# │   ├── reverb-checkpoint.ipynb
# │   └── vintageandrare-checkpoint.ipynb
# ├── alembic/
# │   ├── .DS_Store
# │   ├── README
# │   ├── env.py
# │   └── script.py.mako
# │   ├── versions/
# │   │   ├── .DS_Store
# │   │   ├── 4ee276a8ccca_create_platform_specific_tables.py
# │   │   └── d76101de8296_initial_database_setup.py
